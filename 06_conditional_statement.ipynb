# %% [markdown]
#  ## Introduction of conditonal Statement

# %% [markdown]
# A conditional statement is used to make decisions in a program. It allows the program to execute different blocks of code based on whether a specified condition is True or False.

# %% [markdown]
#  ## Type of Conditional  Statement

# %% [markdown]
# - . If statement

# %% [markdown]
# The if statement executes a block of code only when the condition is True

# %% [markdown]
#  ## If-else Statement

# %% [markdown]
# The if-else statement executes one block of code if the condition is True, otherwise it executes another block.

# %% [markdown]
# ## If-elif-else Statement

# %% [markdown]
# The if-elif-else statement is used to check multiple conditions.

# %% [markdown]
#  ## Examples :-

# %%
num1=int(input("enter the value here"))
num2=int(input("enter the value here"))
if num1>num2:
    print("num1 is greater than num2 ")
else:
    print("the num2 is greater than num1")
# Out:
# enter the value here 122
# enter the value here 100
# num1 is greater than num2

# %%
marks=80
if marks >=90:
    print("grade A")
elif marks >=75:
    print("grade B")
else:
    print("grade C")
# Out:
# grade B

# %%
age=18
if age>=18:
    print("eligible to vote")
elif age<=18:
    print(" not eligible to vote")
# Out:
# eligible to vote

# %%
books_cash=100
if book_cash>=100:
    print(

# %%
age=34
if(age>=18):         #nesting statement
    if(age>=80):
        print("cannot drive")
    print("can drive")
else:
    print("cannot drive")
# Out:
# can drive

# %%
num=int(input("enter the value here"))
if (num %2==0):
    print("the number is even")
elif (num %2!=0):
    print("the number is odd")
# Out:
# enter the value here 143
# the number is odd

# %%
num1=int(input("enter the first number here"))
num2=int(input("enter the second number here"))
num3=int(input("enter the third number here"))

if (num1>num2)and (num1>num3):
    print("num1 is greater than num2 and num3 ")
elif (num2>num1)and (num2>num3):
    print("num2 is greater than num1 and num3")
elif(num3>num1)and (num3>num2):
    print("num3 is greater than num1 and num2")
else:
    print("no body has greter each other ")
# Out:
# enter the first number here 121
# enter the second number here 234
# enter the third number here 342
# num3 is greater than num1 and num2

# %%
x=int(input("enter the number here"))
if (x %7==0):
  print("the multiple of 7")
else:
  print("not multiple of 7")
# Out:
# enter the number here 34
# not multiple of 7

# %%
t-shirt="enter a color of t-shirt"
if (t-shirt= green):
    print("t-shirt has green color")
elif(t-shirt= blue):
    print("t-shirt has blue color")
elif(t-shirt= red):
    print("t-shirt has red color")
else:
    print("t-shit has pink color")
# Out:
#   Cell In[13], line 1
#     t-shirt="enter a color of t-shirt"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?
