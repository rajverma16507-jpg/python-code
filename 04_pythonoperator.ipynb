# %%
print(13/4)
# Out:
# 3.25

# %%
print(13//4)
# Out:
# 3

# %%
a=15
b=3
print(a/b)
# Out:
# 5.0

# %%
a=188
b=9
print(a//b)
# Out:
# 20

# %%
a=133
b=9
print(a*b)
# Out:
# 1197

# %%
a=12
b=8
print(a**b)
# Out:
# 429981696

# %%
a=12
b=8
print(a%b)
# Out:
# 4

# %%
a=1222
b=1222
print(a==b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# True
# False
# False
# True
# True

# %%
username="rajverma123"
passward="1122"
user_name_by_user="rajverma13"
passward_by_user="1122"
print(username==user_name_by_user and passward == passward_by_user)
print(username==user_name_by_user or passward == passward_by_user)
# Out:
# False
# True

# %%
str="this is a pyhton program "
print("is" in str)
# Out:
# True

# %%
str="this is a pyhton program "
print("here" in str )
# Out:
# False

# %%
str="this is a pyhton program "
print(" has" not in str)
# Out:
# True

# %%
data=[12,56,78,54]
print(54 in data)
# Out:
# True

# %%
data=[45,767,86,45]
print(32 not in data)
# Out:
# True

# %%
list1=[56,7,65,45]
list2=[56,7,65,45]
print(list1== list2)
print(list1 is list2)
print(id(list1))
print(id(list2))
# Out:
# True
# False
# 2453961643968
# 2453961668032

# %%
print(112+4332)
print(234-898)
print(45*8)
print(894/2)
print(67%3)
print(45**2)
print(85//3)
# Out:
# 4444
# -664
# 360
# 447.0
# 1
# 2025
# 28

# %%
a=111
b=343
print(a==b)
print(a!=b)
print(a>b)
print(a>=b)
print(a<b)
print(a<=b)
# Out:
# False
# True
# False
# False
# True
# True

# %%
num1=int(input("enter the number here"))
num2=int(input("enter the number here"))
num3=int(input("enter the number here"))
if (num1>num2)and(num1>num3):
    print("the num1 is greaten than num2 and num3")
elif (num2>num1)and(num2>num3):
    print("the num2 is greater than num1 and num3")
else:
    print("the num3 is greater than num1 and num2 ")
# Out:
# enter the number here 122
# enter the number here 78
# enter the number here 89
# the num1 is greaten than num2 and num3

# %%
subject="python"
class_id="2547"
subject_name="pytho"
class_id_user="2547"
print(subject==subject_name and class_id==class_id_user)
print(subject==subject_name or class_id==class_id_user)
# Out:
# False
# True

# %%
str="i am  python coder"
print( "am" in str )
print("here" in str)
# Out:
# True
# False

# %%
key=[12,45,67,87]
print(12 in key)
# Out:
# True

# %%
numb=[477,898,455,654,766 ]
print( 344 in numb)
# Out:
# False

# %%
#practice question

# %%
num1=40
num2=50
total=num1+num2
print(total)
# Out:
# 90

# %%
num1=50
num2=18
sub=num1-num2
print(sub)
# Out:
# 32

# %%
num1=9
num2=7
mul=num1*num2
print(mul)
# Out:
# 63

# %%
numb1=5000
numb2=2
remin=5000%2
print(remin)
# Out:
# 0

# %%
num1=29
num2=5
floor=29//5
print(floor)
# Out:
# 5

# %%
num=12
num**=2
print(num)
# Out:
# 144

# %%
num=5
num**=3
print(num)
# Out:
# 125

# %%
#relational operator

# %%
num1=10
num2=5
print(num1>num2)
# Out:
# True

# %%
num1=15
num2=25
print(num1<num2)
# Out:
# True

# %%
num1=20 
num2=20
print(num1==num2)
# Out:
# True

# %%
num1=30
num2=10
print(num1!=num2)
# Out:
# True

# %%
num1=45
num2=40
print(num1>=num2)
# Out:
# True

# %%
num1=8
num2=3
print(num1<=num2)
# Out:
# False

# %%
#logical operator

# %%
name="raj verma"
ducat_id=3444
name_user="raj verma"
ducat_id_by_user=3444
print(name==name_user and ducat_id==ducat_id_by_user)
# Out:
# True

# %%
name="raj verma"
ducat_id=3444
name_user="raj verma"
ducat_id_by_user=3446
print(name==name_user or ducat_id==ducat_id_by_user)
# Out:
# True

# %%
#assignment operator

# %%
x=10
x=x+5
x+=5
print(x)
# Out:
# 20

# %%
x=20
x=x-4
x-=4
print(x)
# Out:
# 12

# %%
x=6
x=x*3
x*=3
print(x)
# Out:
# 54

# %%
x=40
x=x/2
x/=2
print(x)
# Out:
# 10.0

# %%
x=5
x**=2
print(x)
# Out:
# 25

# %%
x=20
x=x%3
print(x)
# Out:
# 2

# %%
#identity operator

# %%
a=10
b=10
print( a is b)
# Out:
# True

# %%
num1=[1,2,3]
num2=[1,2,3]
print(num1 is num2)
# Out:
# False

# %%
a=12
b=13
print(a  is not b)
print(id(a))
print(id(b))
# Out:
# True
# 140729639150856
# 140729639150888

# %%
#memership opertaor

# %%
string="apple"
print("a" in string )
# Out:
# True

# %%
string="pyhton"
print("x" in string)
# Out:
# False

# %%
num=[1,2,3,4,5]
print(3 in num)
# Out:
# True

# %%
25&12
# Out:
# 8

# %%
25|12
# Out:
# 29
